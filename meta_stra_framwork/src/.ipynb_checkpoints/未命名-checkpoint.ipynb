# %%
import main

# %%
results = main.singel_expre_test()
# Out:
# 600000.XSHG copy finished.
# 600004.XSHG copy finished.
# 600009.XSHG copy finished.
# 600010.XSHG copy finished.
# 600011.XSHG copy finished.
# 600015.XSHG copy finished.
# 600016.XSHG copy finished.
# 600018.XSHG copy finished.
# 600019.XSHG copy finished.
# 600023.XSHG copy finished.
# 600025.XSHG copy finished.
# 600027.XSHG copy finished.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-2c8b3b5bc961> in <module>
# ----> 1 results = main.singel_expre_test(True)
#
# ~/Documents/signal_framework/big/meta_stra_framwork/src/main.py in singel_expre_test(off_line)
#      80     param =  params.PARAMS
#      81     if(param['get_code_data']):
# ---> 82         copydata.main(param['code_list'])
#      83     ori_expre,code_list = param['_Expression'],param['code_list']
#      84     _code_list = copy.copy(code_list)
#
# ...
