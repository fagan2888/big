# %%
import main

# %%
results = main.singel_expre_test()
# Out:
# calindex 600928.XSHG Length of values does not match length of index
# calindex 600968.XSHG [Errno 2] No such file or directory: '/Users/wode/Documents/signal_framework/big/meta_stra_framwork/wmdata/600968.XSHG'
# calindex 600989.XSHG [Errno 2] No such file or directory: '/Users/wode/Documents/signal_framework/big/meta_stra_framwork/wmdata/600989.XSHG'
# calindex 601236.XSHG [Errno 2] No such file or directory: '/Users/wode/Documents/signal_framework/big/meta_stra_framwork/wmdata/601236.XSHG'
# calindex 601698.XSHG [Errno 2] No such file or directory: '/Users/wode/Documents/signal_framework/big/meta_stra_framwork/wmdata/601698.XSHG'
# calindex 603501.XSHG [Errno 2] No such file or directory: '/Users/wode/Documents/signal_framework/big/meta_stra_framwork/wmdata/603501.XSHG'
# calindex 603899.XSHG [Errno 2] No such file or directory: '/Users/wode/Documents/signal_framework/big/meta_stra_framwork/wmdata/603899.XSHG'
# ...
